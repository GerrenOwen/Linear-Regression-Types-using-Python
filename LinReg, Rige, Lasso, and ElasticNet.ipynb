# %%
>>> import numpy as np
>>> from sklearn.linear_model import LinearRegression

# %%
>>> X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])

# %%
X
# Out:
# array([[1, 1],
#        [1, 2],
#        [2, 2],
#        [2, 3]])

# %%
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()

# %%
>>> y = np.dot(X, np.array([1, 2])) + 3

# %%
y
# Out:
# array([ 6,  8,  9, 11])

# %%
reg = LinearRegression().fit(X, y)

# %%
reg.score(X, y)
# Out:
# 1.0

# %%
reg.coef_
# Out:
# array([1., 2.])

# %%
reg.intercept_
# Out:
# 3.000000000000001

# %%
reg.predict(np.array([[3, 5]]))
# Out:
# array([16.])

# %%
reg.predict(np.array([[4, 5]]))
# Out:
# array([17.])

# %%
reg.predict(np.array([[3, 4]]))
# Out:
# array([14.])

# %%
import pandas as pd

# %%
sb.set()

# %%
linea = pd.read_csv("mockdata_regress.csv")

# %%
linea.head()
# Out:
#       X1      X2      X3         y
# 0  14.86  49.380  56.530  114.0590
# 1  15.40  48.935  56.530  130.8425
# 2  14.50  49.825  58.045  129.2560
# 3  15.40  51.160  58.550  150.3815
# 4  15.04  45.820  56.025  102.2855

# %%
X = linea2[['X1','X2','X3']]
y = linea['y']

# %%
X
# Out:
# array([[1, 1],
#        [1, 2],
#        [2, 2],
#        [2, 3]])

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
scaler = StandardScaler()

# %%
scaler.fit(linea.drop('y', axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(linea.drop('y', axis=1))

# %%
linea2= pd.DataFrame(scaled_features,columns=linea.columns[:-1])
linea2.head()
# Out:
#          X1        X2        X3
# 0 -0.092042  0.139530  0.068347
# 1  0.264365  0.089357  0.068347
# 2 -0.329647  0.189703  0.192745
# 3  0.264365  0.340220  0.234211
# 4  0.026760 -0.261851  0.026880

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 101)

# %%
linreg = LinearRegression()

# %%
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
l1_y_train_pred = linreg.predict(X_train)
l1_y_test_pred = linreg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, l1_y_train_pred))
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.8690434606157702
# Mean Squared Error (MSE) 	: 877.979443170889

# %%
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, l1_y_test_pred))
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.867976478024417
# Mean Squared Error (MSE) 	: 872.9639186976796

# %%
from sklearn.linear_model import Ridge

# %%
rireg = Ridge(alpha=10.0)

# %%
rireg.fit(X_train,y_train)
# Out:
# Ridge(alpha=10.0)

# %%
l2_y_train_pred = rireg.predict(X_train)
l2_y_test_pred = rireg.predict(X_test)

# %%
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", rireg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, l2_y_train_pred))
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.8690372322038316
# Mean Squared Error (MSE) 	: 878.0212006705261

# %%
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", rireg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, l2_y_test_pred))
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8681368167045402
# Mean Squared Error (MSE) 	: 871.903729722073

# %%
from sklearn.linear_model import Lasso

# %%
lareg = Lasso(alpha=10.0)

# %%
lareg.fit(X_train,y_train)
# Out:
# Lasso(alpha=10.0)

# %%
l3_y_train_pred = lareg.predict(X_train)
l3_y_test_pred = lareg.predict(X_test)

# %%
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", lareg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, l3_y_train_pred))
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.8530834901068802
# Mean Squared Error (MSE) 	: 984.9807894672043

# %%
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", lareg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, l3_y_test_pred))
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8475625199723371
# Mean Squared Error (MSE) 	: 1007.9447808244262

# %%
from sklearn.linear_model import ElasticNet

# %%
ENreg = ElasticNet(alpha=10.0, l1_ratio = 1.0)

# %%
ENreg.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=10.0, l1_ratio=1.0)

# %%
l4_y_train_pred = ENreg.predict(X_train)
l4_y_test_pred = ENreg.predict(X_test)

# %%
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", ENreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, l4_y_train_pred))
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.8530834901068802
# Mean Squared Error (MSE) 	: 984.9807894672043

# %%
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", ENreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, l4_y_test_pred))
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8475625199723371
# Mean Squared Error (MSE) 	: 1007.9447808244262

# %%
X1 = linea2['X1']

# %%
X1
# Out:
# 0       14.86
# 1       15.40
# 2       14.50
# 3       15.40
# 4       15.04
#         ...
# 3995    16.12
# 3996    16.12
# 3997    15.76
# 3998    17.38
# 3999    16.30
# Name: X1, Length: 4000, dtype: float64

# %%
y1 = linea['y']

# %%
y
# Out:
# 0       114.0590
# 1       130.8425
# 2       129.2560
# 3       150.3815
# 4       102.2855
#           ...
# 3995    229.0385
# 3996    214.0920
# 3997    202.6525
# 3998    239.3925
# 3999    193.8850
# Name: y, Length: 4000, dtype: float64

# %%
X2a = pd.DataFrame(linea2['X2'])
y2a = pd.DataFrame(linea['y'])

# %%
sample = pd.DataFrame.join(X2a,y2a)

# %%
sample
# Out:
#             X2         y
# 0     0.139530  114.0590
# 1     0.089357  130.8425
# 2     0.189703  129.2560
# 3     0.340220  150.3815
# 4    -0.261851  102.2855
# ...        ...       ...
# 3995  1.142982  229.0385
# 3996  0.892119  214.0920
# 3997  0.892119  202.6525
# 3998  1.193155  239.3925
# 3999  1.042637  193.8850
#
# [4000 rows x 2 columns]

# %%
X2a_train, X2a_test, y2a_train, y2a_test = train_test_split(X2a, y2a, test_size=0.3)

# %%
linreg.fit(X2a_train, y2a_train)
# Out:
# LinearRegression()

# %%
f = plt.subplots(1,1, figsize = (14,14))
plt.scatter(X2a,y2a,color='brown')

# %%
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()
# Out:
# Intercept of Regression 	: b =  [138.45634364]
# Coefficients of Regression 	: a =  [[75.94046553]]

# %%
y2a_train_pred = linreg.predict(X2a_train)
y2a_test_pred = linreg.predict(X2a_test)

# %%
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X2a_train, y2a_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_train, y2a_train_pred))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.8585084009299899
# Mean Squared Error (MSE) 	: 962.859663124313

# %%
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X2a_test, y2a_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_test, y2a_test_pred))
print()
# Out:
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8536001764252102
# Mean Squared Error (MSE) 	: 934.2898622417135

# %%
rireg.fit(X2a_train, y2a_train)

print('Intercept of Regression \t: b = ', rireg.intercept_)
print('Coefficients of Regression \t: a = ', rireg.coef_)
print()

y2ar_train_pred = rireg.predict(X2a_train)
y2ar_test_pred = rireg.predict(X2a_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", rireg.score(X2a_train, y2a_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_train, y2ar_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", rireg.score(X2a_test, y2a_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_test, y2ar_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [138.45464085]
# Coefficients of Regression 	: a =  [[75.67368356]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.8584978056857981
# Mean Squared Error (MSE) 	: 962.9317644598005
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8536689453556611
# Mean Squared Error (MSE) 	: 933.8509948101243

# %%
lareg.fit(X2a_train, y2a_train)

print('Intercept of Regression \t: b = ', lareg.intercept_)
print('Coefficients of Regression \t: a = ', lareg.coef_)
print()

y2al_train_pred = lareg.predict(X2a_train)
y2al_test_pred = lareg.predict(X2a_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", lareg.score(X2a_train, y2a_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_train, y2al_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", lareg.score(X2a_test, y2a_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_test, y2al_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [138.39333905]
# Coefficients of Regression 	: a =  [66.069273]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.8440027479378185
# Mean Squared Error (MSE) 	: 1061.5715883922553
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8417390883600115
# Mean Squared Error (MSE) 	: 1009.9845868928686

# %%
ENreg.fit(X2a_train, y2a_train)

print('Intercept of Regression \t: b = ', ENreg.intercept_)
print('Coefficients of Regression \t: a = ', ENreg.coef_)
print()

y2ae_train_pred = ENreg.predict(X2a_train)
y2ae_test_pred = ENreg.predict(X2a_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", ENreg.score(X2a_train, y2a_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_train, y2ae_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", ENreg.score(X2a_test, y2a_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_test, y2ae_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [138.39333905]
# Coefficients of Regression 	: a =  [66.069273]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.8440027479378185
# Mean Squared Error (MSE) 	: 1061.5715883922553
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8417390883600115
# Mean Squared Error (MSE) 	: 1009.9845868928686

# %%
f, axes = plt.subplots(1, 2, figsize=(30, 15))

axes[0].scatter(X2a_train,y2a_train,color='red',label='Train Data')
axes[0].plot(X2a_train.squeeze(), linreg.predict(X2a_train), 'black', linewidth = 1.5, label = 'Linear Regression')
axes[0].plot(X2a_train.squeeze(), rireg.predict(X2a_train), 'yellow', linewidth = 1.5, label = 'Ridge (alpha = 10.0)')
axes[0].plot(X2a_train.squeeze(), lareg.predict(X2a_train), 'purple', linewidth = 1.5, label = 'Lasso (alpha = 10.0)')
axes[0].plot(X2a_train.squeeze(), ENreg.predict(X2a_train), 'green', linewidth = 1.5, label = 'Elastic Net (alpha = 10.0, l1_ratio = 1.0)')
axes[0].set_xlabel("Train value (X2)", fontsize=23)
axes[0].set_ylabel("Train value (y)", fontsize=23)
axes[0].set_title("Train values plot and the Training of the Linear Model (X2 VS y)", fontsize=23)
axes[0].legend(fontsize=14)

axes[1].scatter(X2a_test,y2a_test,color='blue', label='Test Data')
axes[1].plot(X2a_test.squeeze(), linreg.predict(X2a_test), 'black', linewidth = 1.5, label = 'Linear Regression')
axes[1].plot(X2a_test.squeeze(), rireg.predict(X2a_test), 'yellow', linewidth = 1.5, label = 'Ridge (alpha = 10.0)')
axes[1].plot(X2a_test.squeeze(), lareg.predict(X2a_test), 'purple', linewidth = 1.5, label = 'Lasso (alpha = 10.0)')
axes[1].plot(X2a_test.squeeze(), ENreg.predict(X2a_test), 'green', linewidth = 1.5, label = 'Elastic Net (alpha = 10.0, l1_ratio = 1.0)')
axes[1].set_xlabel("Test value (X2)", fontsize=23)
axes[1].set_ylabel("Test value (y)", fontsize=23)
axes[1].set_title("Test values plot and the Training of the Linear Model (X2 vs y)", fontsize=23)
axes[1].legend(fontsize=14)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2, include_bias=False)

# %%
ENreg = ElasticNet(alpha=10.0, l1_ratio = 1.0)
#l1_ratio = 1 is by default Lasso l1 penalty function

# %%
i = 0.0
RMSEtrainingEN = []
RMSEtestEN = []
while i < 1.0:
    experi = ElasticNet(alpha=10.0, l1_ratio = i)
    experi.fit(X2a_train, y2a_train)
    y2aexperi_train_pred = experi.predict(X2a_train)
    y2aexperi_test_pred = experi.predict(X2a_test)
    RMSEtrainingEN.append(np.sqrt(mean_squared_error(y2a_train, y2aexperi_train_pred)))
    RMSEtestEN.append(np.sqrt(mean_squared_error(y2a_test, y2ae_test_pred)))
    i += 0.001
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.775e+06, tolerance: 1.905e+03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %%
RMSEtrainingEN
# Out:
# [75.14565988092116,
#  75.14073694076505,
#  75.13580511155016,
#  75.1308643691934,
#  75.12591468952468,
#  75.12095604828652,
#  75.11598842113358,
#  75.11101178363235,
#  75.10602611126073,
#  75.10103137940757,
#  75.09602756337235,
#  75.0910146383647,
#  75.08599257950405,
#  75.08096136181919,
#  75.07592096024784,
#  75.07087134963628,
#  75.06581250473891,
#  75.06074440021783,
#  75.05566701064238,
#  75.0505803104888,
#  75.04548427413975,
#  75.04037887588386,
#  75.03526408991536,
#  75.03013989033359,
#  75.0250062511426,
#  75.01986314625069,
#  75.01471054946998,
#  75.00954843451598,
#  75.0043767750071,
#  74.99919554446427,
#  74.9940047163104,
#  74.98880426387001,
#  74.98359416036877,
#  74.97837437893291,
#  74.97314489258899,
#  74.96790567426322,
#  74.96265669678114,
#  74.95739793286702,
#  74.95212935514355,
#  74.94685093613123,
#  74.94156264824795,
#  74.9362644638085,
#  74.9309563550241,
#  74.92563829400191,
#  74.92031025274453,
# ...

# %%
RMSEtestEN
# Out:
# [33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
#  33.10742228668185,
# ...

# %%
f, axes = plt.subplots(1, 2, figsize=(24, 12))

axes[0].plot(RMSEtrainingEN, color='red', label='MRSE training')
axes[0].set_xlabel("l1_ratio (increment: 0.001)", fontsize=17)
axes[0].set_ylabel("MRSE", fontsize=17)
axes[0].set_title("MRSE training on ElasticNet (alpha=10.0) along l1_ratio (X2 vs y)", fontsize = 23)
axes[0].legend(fontsize=14)

axes[1].plot(RMSEtestEN,color='blue', label = 'MRSE test')
axes[1].set_xlabel("l1_ratio (increment: 0.001)", fontsize=17)
axes[1].set_ylabel("MRSE", fontsize=17)
axes[1].set_title("MRSE test on ElasticNet (alpha=10.0) along l1_ratio", fontsize = 23)
axes[1].legend(fontsize=14)

# %%
RMSEtrainingridge = []
RMSEtestridge = []
j = 0.0
while j <= 1000.0:
    experi = Ridge(alpha= j)
    experi.fit(X2a_train, y2a_train)
    y2aexperi_train_pred = experi.predict(X2a_train)
    y2aexperi_test_pred = experi.predict(X2a_test)
    RMSEtrainingridge.append(np.sqrt(mean_squared_error(y2a_train, y2aexperi_train_pred)))
    RMSEtestridge.append(np.sqrt(mean_squared_error(y2a_test, y2ae_test_pred)))
    j += 1.0

# %%
f, axes = plt.subplots(1, 2, figsize=(24, 12))

axes[0].plot(RMSEtrainingridge, color='red', label='MRSE training')
axes[0].set_xlabel("alpha (increment: 1.0)", fontsize=17)
axes[0].set_ylabel("MRSE", fontsize=17)
axes[0].set_title("MRSE training on Ridge along alpha (from 1.0 to 1000.0; X2 vs y)", fontsize = 23)
axes[0].legend(fontsize=14)

axes[1].plot(RMSEtestridge,color='blue', label = 'MRSE test')
axes[1].set_xlabel("alpha Iincrement: 1.0", fontsize=17)
axes[1].set_ylabel("MRSE", fontsize=17)
axes[1].set_title("MRSE test on Ridge along alpha (from 1.0 to 1000.0; X2 vs y)", fontsize = 23)
axes[1].legend(fontsize=14)

# %%
RMSEtraininglasso = []
RMSEtestlasso = []
k = 0.0
while k <= 100.0:
    experi = Lasso(alpha= k)
    experi.fit(X2a_train, y2a_train)
    y2aexperi_train_pred = experi.predict(X2a_train)
    y2aexperi_test_pred = experi.predict(X2a_test)
    RMSEtraininglasso.append(np.sqrt(mean_squared_error(y2a_train, y2aexperi_train_pred)))
    RMSEtestlasso.append(np.sqrt(mean_squared_error(y2a_test, y2ae_test_pred)))
    k += 1.0
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7120\2593661623.py:6: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   experi.fit(X2a_train, y2a_train)
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.348e+06, tolerance: 1.905e+03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# ...

# %%
f, axes = plt.subplots(1, 2, figsize=(24, 12))

axes[0].plot(RMSEtraininglasso, color='red', label='MRSE training')
axes[0].set_xlabel("alpha (increment: 1.0)", fontsize=17)
axes[0].set_ylabel("MRSE", fontsize=17)
axes[0].set_title("MRSE training on Lasso along alpha (from 1.0 to 100.0; X2 vs y)", fontsize = 23)
axes[0].legend(fontsize=14)

axes[1].plot(RMSEtestlasso,color='blue', label = 'MRSE test')
axes[1].set_xlabel("alpha (increment: 1.0)", fontsize=17)
axes[1].set_ylabel("MRSE", fontsize=17)
axes[1].set_title("MRSE test on Lasso along alpha (from 1.0 to 100.0; X2 vs y)", fontsize = 23)
axes[1].legend(fontsize=14)

# %%
X1a = pd.DataFrame(linea2['X1'])
y2a = pd.DataFrame(linea['y'])

X1a_train, X1a_test, y2a_train, y2a_test = train_test_split(X1a, y2a, test_size=0.3)

# %%
RMSEtraininglasso2 = []
RMSEtestlasso2 = []
l = 0.0
while l <= 100.0:
    experi = Lasso(alpha= l)
    experi.fit(X1a_train, y2a_train)
    y2aexperi_train_pred = experi.predict(X1a_train)
    y2aexperi_test_pred = experi.predict(X1a_test)
    RMSEtraininglasso2.append(np.sqrt(mean_squared_error(y2a_train, y2aexperi_train_pred)))
    RMSEtestlasso2.append(np.sqrt(mean_squared_error(y2a_test, y2ae_test_pred)))
    l += 1.0
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7120\2642248201.py:6: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   experi.fit(X1a_train, y2a_train)
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:647: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.535e+06, tolerance: 1.898e+03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# ...

# %%
f, axes = plt.subplots(1, 2, figsize=(24, 12))

axes[0].plot(RMSEtraininglasso2, color='red', label='MRSE training')
axes[0].set_xlabel("alpha (increment: 1.0)", fontsize=17)
axes[0].set_ylabel("MRSE", fontsize=17)
axes[0].set_title("MRSE training on Lasso along alpha (from 1.0 to 100.0; X1 vs y)", fontsize = 23)
axes[0].legend(fontsize=14)

axes[1].plot(RMSEtestlasso2,color='blue', label = 'MRSE test')
axes[1].set_xlabel("alpha (increment: 1.0)", fontsize=17)
axes[1].set_ylabel("MRSE", fontsize=17)
axes[1].set_title("MRSE test on Lasso along alpha (from 1.0 to 100.0; X1 vs y)", fontsize = 23)
axes[1].legend(fontsize=14)

# %%
linreg.fit(X1a_train, y2a_train)

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

y2ar_train_pred = linreg.predict(X1a_train)
y2ar_test_pred = linreg.predict(X1a_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X1a_train, y2a_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_train, y2ar_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X1a_test, y2a_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_test, y2ar_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [137.70412892]
# Coefficients of Regression 	: a =  [[62.85413566]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6275560640376212
# Mean Squared Error (MSE) 	: 2524.7416655151706
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.761707485832356
# Mean Squared Error (MSE) 	: 1535.0401837939405

# %%
rireg.fit(X1a_train, y2a_train)

print('Intercept of Regression \t: b = ', rireg.intercept_)
print('Coefficients of Regression \t: a = ', rireg.coef_)
print()

y2ar_train_pred = rireg.predict(X1a_train)
y2ar_test_pred = rireg.predict(X1a_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", rireg.score(X1a_train, y2a_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_train, y2ar_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", rireg.score(X1a_test, y2a_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_test, y2ar_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [137.70598642]
# Coefficients of Regression 	: a =  [[62.64635891]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.627549206333976
# Mean Squared Error (MSE) 	: 2524.788152861187
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.7608476389426084
# Mean Squared Error (MSE) 	: 1540.5791724284895

# %%
lareg.fit(X1a_train, y2a_train)

print('Intercept of Regression \t: b = ', lareg.intercept_)
print('Coefficients of Regression \t: a = ', lareg.coef_)
print()

y2al_train_pred = lareg.predict(X1a_train)
y2al_test_pred = lareg.predict(X1a_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", lareg.score(X1a_train, y2a_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_train, y2al_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", lareg.score(X1a_test, y2a_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_test, y2al_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [137.78715052]
# Coefficients of Regression 	: a =  [53.56748418]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6138566148034225
# Mean Squared Error (MSE) 	: 2617.6081802748176
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.7125304523635458
# Mean Squared Error (MSE) 	: 1851.8303387767155

# %%
ENreg.fit(X1a_train, y2a_train)

print('Intercept of Regression \t: b = ', ENreg.intercept_)
print('Coefficients of Regression \t: a = ', ENreg.coef_)
print()

y2ae_train_pred = ENreg.predict(X1a_train)
y2ae_test_pred = ENreg.predict(X1a_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", ENreg.score(X1a_train, y2a_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_train, y2ae_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", ENreg.score(X1a_test, y2a_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2a_test, y2ae_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [137.78715052]
# Coefficients of Regression 	: a =  [53.56748418]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6138566148034225
# Mean Squared Error (MSE) 	: 2617.6081802748176
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.7125304523635458
# Mean Squared Error (MSE) 	: 1851.8303387767155

# %%
f, axes = plt.subplots(1, 2, figsize=(30, 15))

axes[0].scatter(X1a_train,y2a_train,color='green',label='Train Data')
axes[0].plot(X1a_train.squeeze(), linreg.predict(X1a_train), 'black', linewidth = 1.5, label = 'Linear Regression')
axes[0].plot(X1a_train.squeeze(), rireg.predict(X1a_train), 'blue', linewidth = 1.5, label = 'Ridge (alpha = 10.0)')
axes[0].plot(X1a_train.squeeze(), lareg.predict(X1a_train), 'purple', linewidth = 1.5, label = 'Lasso (alpha = 10.0)')
axes[0].plot(X1a_train.squeeze(), ENreg.predict(X1a_train), 'red', linewidth = 1.5, label = 'Elastic Net (alpha = 10.0, l1_ratio = 1.0)')
axes[0].set_xlabel("Train value (X1)", fontsize=23)
axes[0].set_ylabel("Train value (y)", fontsize=23)
axes[0].set_title("Train values plot and the Training of the Linear Model (X1 vs y)", fontsize=23)
axes[0].legend(fontsize=16)

axes[1].scatter(X1a_test,y2a_test,color='yellow', label='Test Data')
axes[1].plot(X1a_test.squeeze(), linreg.predict(X1a_test), 'black', linewidth = 1.5, label = 'Linear Regression')
axes[1].plot(X1a_test.squeeze(), rireg.predict(X1a_test), 'blue', linewidth = 1.5, label = 'Ridge (alpha = 10.0)')
axes[1].plot(X1a_test.squeeze(), lareg.predict(X1a_test), 'purple', linewidth = 1.5, label = 'Lasso (alpha = 10.0)')
axes[1].plot(X1a_test.squeeze(), ENreg.predict(X1a_test), 'red', linewidth = 1.5, label = 'Elastic Net (alpha = 10.0, l1_ratio = 1.0)')
axes[1].set_xlabel("Test value (X2)", fontsize=23)
axes[1].set_ylabel("Test value (y)", fontsize=23)
axes[1].set_title("Test values plot and the Training of the Linear Model (X1 vs y)", fontsize=23)
axes[1].legend(fontsize=16)

# %%
X1b = X1a.loc[:399]
X1b
# Out:
#            X1
# 0   -0.092042
# 1    0.264365
# 2   -0.329647
# 3    0.264365
# 4    0.026760
# ..        ...
# 395  0.501970
# 396  0.264365
# 397  0.620773
# 398  0.620773
# 399  0.264365
#
# [400 rows x 1 columns]

# %%
y2b = y2a.loc[:399]
y2b
# Out:
#             y
# 0    114.0590
# 1    130.8425
# 2    129.2560
# 3    150.3815
# 4    102.2855
# ..        ...
# 395  172.4255
# 396  185.1175
# 397  197.6425
# 398  177.3520
# 399  155.1410
#
# [400 rows x 1 columns]

# %%
X1b_train, X1b_test, y2b_train, y2b_test = train_test_split(X1b, y2b, test_size=0.3)

# %%
linreg.fit(X1b_train, y2b_train)

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

y2ar_train_pred = linreg.predict(X1b_train)
y2ar_test_pred = linreg.predict(X1b_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X1b_train, y2b_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2b_train, y2ar_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X1b_test, y2b_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2b_test, y2ar_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [132.76777356]
# Coefficients of Regression 	: a =  [[82.83664703]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6601434616513262
# Mean Squared Error (MSE) 	: 1584.836553697159
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.6795757112731033
# Mean Squared Error (MSE) 	: 1558.2104485761665

# %%
rireg.fit(X1b_train, y2b_train)

print('Intercept of Regression \t: b = ', rireg.intercept_)
print('Coefficients of Regression \t: a = ', rireg.coef_)
print()

y2ar_train_pred = rireg.predict(X1b_train)
y2ar_test_pred = rireg.predict(X1b_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", rireg.score(X1b_train, y2b_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2b_train, y2ar_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", rireg.score(X1b_test, y2b_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2b_test, y2ar_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [134.53289732]
# Coefficients of Regression 	: a =  [[76.72840826]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6565540331065394
# Mean Squared Error (MSE) 	: 1601.5749621806408
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.6772656548092713
# Mean Squared Error (MSE) 	: 1569.444160393225

# %%
lareg.fit(X1b_train, y2b_train)

print('Intercept of Regression \t: b = ', lareg.intercept_)
print('Coefficients of Regression \t: a = ', lareg.coef_)
print()

y2al_train_pred = lareg.predict(X1b_train)
y2al_test_pred = lareg.predict(X1b_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", lareg.score(X1b_train, y2b_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2b_train, y2al_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", lareg.score(X1b_test, y2b_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2b_test, y2al_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [139.20912514]
# Coefficients of Regression 	: a =  [60.54624778]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6123433405137071
# Mean Squared Error (MSE) 	: 1807.7405461233109
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.6337896414162093
# Mean Squared Error (MSE) 	: 1780.8662676269455

# %%
ENreg.fit(X1b_train, y2b_train)

print('Intercept of Regression \t: b = ', ENreg.intercept_)
print('Coefficients of Regression \t: a = ', ENreg.coef_)
print()

y2ae_train_pred = ENreg.predict(X1b_train)
y2ae_test_pred = ENreg.predict(X1b_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", ENreg.score(X1b_train, y2b_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2b_train, y2ae_train_pred))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", ENreg.score(X1b_test, y2b_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y2b_test, y2ae_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [139.20912514]
# Coefficients of Regression 	: a =  [60.54624778]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6123433405137071
# Mean Squared Error (MSE) 	: 1807.7405461233109
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.6337896414162093
# Mean Squared Error (MSE) 	: 1780.8662676269455

# %%
f, axes = plt.subplots(1, 2, figsize=(30, 15))

axes[0].scatter(X1b_train,y2b_train,color='green',label='Train Data')
axes[0].plot(X1b_train.squeeze(), linreg.predict(X1b_train), 'black', linewidth = 1.5, label = 'Linear Regression')
axes[0].plot(X1b_train.squeeze(), rireg.predict(X1b_train), 'blue', linewidth = 1.5, label = 'Ridge (alpha = 10.0)')
axes[0].plot(X1b_train.squeeze(), lareg.predict(X1b_train), 'purple', linewidth = 1.5, label = 'Lasso (alpha = 10.0)')
axes[0].plot(X1b_train.squeeze(), ENreg.predict(X1b_train), 'red', linewidth = 1.5, label = 'Elastic Net (alpha = 10.0, l1_ratio = 1.0)')
axes[0].set_xlabel("Train value (X1)", fontsize=23)
axes[0].set_ylabel("Train value (y)", fontsize=23)
axes[0].set_title("Train values plot and the Training of the Linear Model (X1 vs y; 400 first rows)", fontsize=23)
axes[0].legend(fontsize=16)

axes[1].scatter(X1b_test,y2b_test,color='brown', label='Test Data')
axes[1].plot(X1b_test.squeeze(), linreg.predict(X1b_test), 'black', linewidth = 1.5, label = 'Linear Regression')
axes[1].plot(X1b_test.squeeze(), rireg.predict(X1b_test), 'blue', linewidth = 1.5, label = 'Ridge (alpha = 10.0)')
axes[1].plot(X1b_test.squeeze(), lareg.predict(X1b_test), 'purple', linewidth = 1.5, label = 'Lasso (alpha = 10.0)')
axes[1].plot(X1b_test.squeeze(), ENreg.predict(X1b_test), 'red', linewidth = 1.5, label = 'Elastic Net (alpha = 10.0, l1_ratio = 1.0)')
axes[1].set_xlabel("Test value (X2)", fontsize=23)
axes[1].set_ylabel("Test value (y)", fontsize=23)
axes[1].set_title("Test values plot and the Training of the Linear Model (X1 vs y; 400 first rows)", fontsize=23)
axes[1].legend(fontsize=16)
